# %%
import deeplabcut
# Out:
# Loading DLC 2.2.3...

# %%
dir(deeplabcut)
# Out:
# ['CropVideo',
#  'DEBUG',
#  'DownSampleVideo',
#  'ShortenVideo',
#  'SkeletonBuilder',
#  'VERSION',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  'add_new_videos',
#  'adddatasetstovideolistandviceversa',
#  'analyze_time_lapse_frames',
#  'analyze_videos',
#  'analyze_videos_converth5_to_csv',
#  'analyze_videos_converth5_to_nwb',
#  'analyzeskeleton',
#  'auxfun_videos',
#  'auxiliaryfunctions',
#  'calibrate_cameras',
#  'check_labels',
#  'check_undistortion',
#  'check_video_integrity',
#  'comparevideolistsanddatafolders',
#  'convert2_maDLC',
#  'convert_detections2tracklets',
#  'convertcsv2h5',
#  'create_labeled_video',
#  'create_labeled_video_3d',
#  'create_multianimaltraining_dataset',
#  'create_new_project',
#  'create_new_project_3d',
#  'create_pretrained_human_project',
#  'create_pretrained_project',
#  'create_project',
# ...

# %%
config_path=deeplabcut.create_new_project("PLUS_MAZE_TEST_TRIAL1","Francois",["C:\\Documents\\APT 2A\\Stage 2A\\DLC\\maze_training_vids\\T1.mp4","C:\\Documents\\APT 2A\\Stage 2A\\DLC\\maze_training_vids\\T2.mp4","C:\\Documents\\APT 2A\\Stage 2A\\DLC\\maze_training_vids\\T3.mp4"],working_directory="C:\\Documents\\APT 2A\\Stage 2A\\DLC\\PLUS_MAZE_WORKING_DIRECTORY",copy_videos= False, multianimal= False)
# Out:
# Created "C:\Documents\APT 2A\Stage 2A\DLC\PLUS_MAZE_WORKING_DIRECTORY\PLUS_MAZE_TEST_TRIAL1-Francois-2023-07-27\videos"
# Created "C:\Documents\APT 2A\Stage 2A\DLC\PLUS_MAZE_WORKING_DIRECTORY\PLUS_MAZE_TEST_TRIAL1-Francois-2023-07-27\labeled-data"
# Created "C:\Documents\APT 2A\Stage 2A\DLC\PLUS_MAZE_WORKING_DIRECTORY\PLUS_MAZE_TEST_TRIAL1-Francois-2023-07-27\training-datasets"
# Created "C:\Documents\APT 2A\Stage 2A\DLC\PLUS_MAZE_WORKING_DIRECTORY\PLUS_MAZE_TEST_TRIAL1-Francois-2023-07-27\dlc-models"
# Attempting to create a symbolic link of the video ...
# Created the symlink of C:\Documents\APT 2A\Stage 2A\DLC\maze_training_vids\T1.mp4 to C:\Documents\APT 2A\Stage 2A\DLC\PLUS_MAZE_WORKING_DIRECTORY\PLUS_MAZE_TEST_TRIAL1-Francois-2023-07-27\videos\T1.mp4
# Created the symlink of C:\Documents\APT 2A\Stage 2A\DLC\maze_training_vids\T2.mp4 to C:\Documents\APT 2A\Stage 2A\DLC\PLUS_MAZE_WORKING_DIRECTORY\PLUS_MAZE_TEST_TRIAL1-Francois-2023-07-27\videos\T2.mp4
# ...

# %%
#Change this path only when you move the files
config_path= r""
#config_path=r"/home/jaime/Github/PLUS_MAZE_WORKING_DIRECTORY/PLUS_MAZE_TEST_TRIAL1-Francois-2023-07-27/config.yaml"
#config_path=r"C:\Documents\APT 2A\Stage 2A\DLC\PLUS_MAZE_WORKING_DIRECTORY\PLUS_MAZE_TEST_TRIAL1-Francois-2023-07-27\config.yaml"
config_path=r"C:\PLUS_MAZE_WORKING_DIRECTORY\PLUS_MAZE_TEST_TRIAL1-Francois-2023-07-27\config.yaml"

# %%
deeplabcut.extract_frames(config_path, mode='automatic', algo='kmeans', userfeedback=False, crop=False)
# Out:
# Config file read successfully.
# Extracting frames based on kmeans ...
# Kmeans-quantization based extracting of frames from 0.0  seconds to 358.05  seconds.
# Extracting and downsampling... 16936  frames from the video.
# 16936it [01:05, 259.80it/s]
# C:\ProgramData\anaconda3\envs\DLCtest\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 3 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# Kmeans clustering ... (this might take a while)
# Extracting frames based on kmeans ...
# Kmeans-quantization based extracting of frames from 0.0  seconds to 358.01  seconds.
# Extracting and downsampling... 16934  frames from the video.
# 16934it [01:06, 253.59it/s]
# ...

# %%
deeplabcut.label_frames(config_path)

# %%
deeplabcut.check_labels(config_path)
# Out:
# Creating images with labels by Francois.
# ...
# 100%|██████████████████████████████████████████████████████████████████████████████████| 20/20 [00:03<00:00,  5.00it/s]
# If all the labels are ok, then use the function 'create_training_dataset' to create the training dataset!

# %%
#train_network
#deeplabcut.train_network(config_path)
#deeplabcut.train_network(config_path, shuffle=1, trainingsetindex=0, gputouse=None, max_snapshots_to_keep=5, autotune=False, displayiters=100, saveiters=15000, maxiters=30000, allow_growth=True)

#Evaluate trained network
#deeplabcut.evaluate_network(config_path,Shuffles=[1], plotting=True)

#Evaluate a novel video:
#deeplabcut.analyze_videos(config_path, ['fullpath/analysis/project/videos/reachingvideo1.avi'], save_as_csv=True)
#deeplabcut.analyze_videos(config_path, videos, videotype='avi', shuffle=1, trainingsetindex=0, gputouse=None, save_as_csv=False, destfolder=None, dynamic=(True, .5, 10))

# %%
#Run this code on the computer where you will run the Network Training
deeplabcut.create_training_dataset(config_path)
# Out:
# The training dataset is successfully created. Use the function 'train_network' to start training. Happy training!
# [(0.95,
#   1,
#   (array([44, 20,  6,  2, 16, 38, 21, 55, 32, 25,  3, 56, 48, 33, 37, 41, 52,
#           43, 53, 50, 27, 19, 12, 24, 10, 34,  8, 30, 15, 18, 11, 31, 26,  4,
#           28, 14,  1, 23, 47, 45,  5, 22, 39, 29, 36, 13, 17,  7,  9, 42, 35,
#           51, 49,  0]),
#    array([46, 54, 40])))]

# %%
#On a powerful computer-- Jaime's LINUX
deeplabcut.train_network(config_path)
# Out:
# Config:
# {'all_joints': [[0], [1], [2], [3], [4], [5], [6], [7]],
#  'all_joints_names': ['leftear',
#                       'rightear',
#                       'nose',
#                       'center',
#                       'lefthip',
#                       'righthip',
#                       'tailbase',
#                       'tailtip'],
#  'alpha_r': 0.02,
#  'apply_prob': 0.5,
#  'batch_size': 1,
#  'clahe': True,
#  'claheratio': 0.1,
#  'crop_pad': 0,
#  'crop_sampling': 'hybrid',
#  'crop_size': [400, 400],
#  'cropratio': 0.4,
#  'dataset': 'training-datasets/iteration-0/UnaugmentedDataSet_PLUS_MAZE_TEST_TRIAL1Jul27/PLUS_MAZE_TEST_TRIAL1_Francois95shuffle1.mat',
#  'dataset_type': 'default',
#  'decay_steps': 30000,
#  'deterministic': False,
#  'display_iters': 1000,
#  'edge': False,
#  'emboss': {'alpha': [0.0, 1.0], 'embossratio': 0.1, 'strength': [0.5, 1.5]},
#  'fg_fraction': 0.25,
#  'global_scale': 0.8,
#  'histeq': True,
#  'histeqratio': 0.1,
# ...

# %%
#deeplabcut.evaluate_network(config_path,Shuffles=[2], plotting=True)
deeplabcut.evaluate_network(config_path,Shuffles=[1], plotting=True)
#had to change to shuffle 1 instead of 2
# Out:
# Running  DLC_resnet50_PLUS_MAZE_TEST_TRIAL1Jul27shuffle1_800000  with # of training iterations: 800000
# This net has already been evaluated!
# Plots already exist for this snapshot... Skipping to the next one.

# %%
# here instead of analyzing a single video, we can put the video directory and it would analyze all the videos with the indicated video type
#deeplabcut.analyze_videos(config_path, ["C:\\DLC_2\\videos\\UNKOWN_OPENFIELD_EVALUATE(2).mp4"], videotype='mp4', shuffle=2, trainingsetindex=0, gputouse=None, save_as_csv=True, destfolder="C:\\DLC_2\\videos\\NOVEL_ANALYSED\\", dynamic=(True, .5, 10))
#deeplabcut.analyze_videos(config_path, ["C:\Documents\APT 2A\Stage 2A\DLC\maze_training_vids"], videotype='mp4', shuffle=1, trainingsetindex=0, gputouse=None, save_as_csv=True, destfolder="C:\Documents\APT 2A\Stage 2A\DLC\maze_training_vids\DLC_analysis", dynamic=(True, .5, 10))
deeplabcut.analyze_videos(config_path, ["C:\Documents\APT 2A\Stage 2A\DLC\maze_training_vids"], videotype='mp4', shuffle=1, trainingsetindex=0, gputouse=None, save_as_csv=True, dynamic=(True, .5, 10))
# Out:
# Using snapshot-800000 for model C:\PLUS_MAZE_WORKING_DIRECTORY\PLUS_MAZE_TEST_TRIAL1-Francois-2023-07-27\dlc-models\iteration-0\PLUS_MAZE_TEST_TRIAL1Jul27-trainset95shuffle1
# Starting analysis in dynamic cropping mode with parameters: (True, 0.5, 10)
# Switching batchsize to 1, num_outputs (per animal) to 1 and TFGPUinference to False (all these features are not supported in this mode).
# C:\ProgramData\anaconda3\envs\DLCtest\lib\site-packages\tensorflow\python\keras\engine\base_layer_v1.py:1694: UserWarning: `layer.apply` is deprecated and will be removed in a future version. Please use `layer.__call__` method instead.
#   warnings.warn('`layer.apply` is deprecated and '
# Analyzing all the videos in the directory...
# Starting to analyze %  C:\Documents\APT 2A\Stage 2A\DLC\maze_training_vids\T2.mp4
# Loading  C:\Documents\APT 2A\Stage 2A\DLC\maze_training_vids\T2.mp4
# Duration of video [s]:  358.01 , recorded with  47.3 fps!
# ...

# %%
deeplabcut.filterpredictions(config_path,  ["C:\\DLC_2\\videos\\OPENFIELD_EVALUATE (2).mp4"], shuffle=2, trainingsetindex=0, filtertype='arima', p_bound=0.01, ARdegree=3, MAdegree=1, alpha=0.01)
# Out:
# Filtering with arima model C:\DLC_2\videos\OPENFIELD_EVALUATE (2).mp4
# Saving filtered csv poses!

# %%
deeplabcut.plot_trajectories(config_path, ["C:\\DLC_2\\videos\\UNKOWN_OPENFIELD_EVALUATE(2).mp4"], videotype='mp4',shuffle=2, destfolder="C:\\DLC_2\\videos\\NOVEL_ANALYSED\\")
# Out:
# Loading  C:\DLC_2\videos\UNKOWN_OPENFIELD_EVALUATE(2).mp4 and data.
# Plots created! Please check the directory "plot-poses" within the video directory

# %%
deeplabcut.SkeletonBuilder(config_path)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 deeplabcut.SkeletonBuilder(config_path)
#
# NameError: name 'config_path' is not defined

# %%
deeplabcut.SkeletonBuilder??
# Out:
# Init signature: deeplabcut.SkeletonBuilder(config_path)
# Docstring:      <no docstring>
# Source:
# class SkeletonBuilder:
#     def __init__(self, config_path):
#         self.config_path = config_path
#         self.cfg = read_config(config_path)
#         # Find uncropped labeled data
#         self.df = None
#         found = False
#         root = os.path.join(self.cfg["project_path"], "labeled-data")
#         for dir_ in os.listdir(root):
#             folder = os.path.join(root, dir_)
#             if os.path.isdir(folder) and not any(
#                 folder.endswith(s) for s in ("cropped", "labeled")
#             ):
#                 self.df = pd.read_hdf(
#                     os.path.join(folder, f'CollectedData_{self.cfg["scorer"]}.h5')
#                 )
#                 row, col = self.pick_labeled_frame()
#                 if "individuals" in self.df.columns.names:
#                     self.df = self.df.xs(col, axis=1, level="individuals")
# ...

# %%
#deeplabcut.create_labeled_video(config_path, ["C:\Documents\APT 2A\Stage 2A\DLC\maze_training_vids"], videotype='.mp4',destfolder="C:\Documents\APT 2A\Stage 2A\DLC\maze_training_vids\DLC_labeled", shuffle=1)
deeplabcut.create_labeled_video(config_path, "C:\Documents\APT 2A\Stage 2A\DLC\maze_training_vids", shuffle=1)
# Out:
# Analyzing all the videos in the directory...
# Starting to process video: C:\Documents\APT 2A\Stage 2A\DLC\maze_training_vids\T2.mp4
# Loading C:\Documents\APT 2A\Stage 2A\DLC\maze_training_vids\T2.mp4 and data.
# Duration of video [s]: 358.01, recorded with 47.3 fps!
# Overall # of frames: 16934 with cropped frame dimensions: 1024 768
# Generating frames and creating video.
# 100%|███████████████████████████████████████████████████████████████████████████| 16934/16934 [01:17<00:00, 219.83it/s]
# Starting to process video: C:\Documents\APT 2A\Stage 2A\DLC\maze_training_vids\T1.mp4
# Loading C:\Documents\APT 2A\Stage 2A\DLC\maze_training_vids\T1.mp4 and data.
# Duration of video [s]: 358.05, recorded with 47.3 fps!
# Overall # of frames: 16936 with cropped frame dimensions: 1024 768
# Generating frames and creating video.
# 100%|███████████████████████████████████████████████████████████████████████████| 16936/16936 [01:16<00:00, 220.49it/s]
# ...

# %%
deeplabcut.create_labeled_video?
# Out:
# Signature:
# deeplabcut.create_labeled_video(
#     config,
#     videos,
#     videotype='',
#     shuffle=1,
#     trainingsetindex=0,
#     filtered=False,
#     fastmode=True,
#     save_frames=False,
#     keypoints_only=False,
#     Frames2plot=None,
#     displayedbodyparts='all',
#     displayedindividuals='all',
#     codec='mp4v',
#     outputframerate=None,
#     destfolder=None,
#     draw_skeleton=False,
#     trailpoints=0,
#     displaycropped=False,
#     color_by='bodypart',
#     modelprefix='',
#     init_weights='',
#     track_method='',
#     superanimal_name='',
#     pcutoff=0.6,
#     skeleton=[],
#     skeleton_color='white',
#     dotsize=8,
#     colormap='rainbow',
#     alphavalue=0.5,
#     overwrite=False,
# )
# Docstring:
# Labels the bodyparts in a video.
#
# Make sure the video is already analyzed by the function
# ``deeplabcut.analyze_videos``.
#
# Parameters
# ----------
# config : string
#     Full path of the config.yaml file.
#
# ...

# %%
deeplabcut.evaluate_network?
# Out:
# Signature:
# deeplabcut.evaluate_network(
#     config,
#     Shuffles=[1],
#     trainingsetindex=0,
#     plotting=False,
#     show_errors=True,
#     comparisonbodyparts='all',
#     gputouse=None,
#     rescale=False,
#     modelprefix='',
# )
# Docstring:
# Evaluates the network.
#
# Evaluates the network based on the saved models at different stages of the training
# network. The evaluation results are stored in the .h5 and .csv file under the
# subdirectory 'evaluation_results'. Change the snapshotindex parameter in the config
# file to 'all' in order to evaluate all the saved models.
#
# Parameters
# ----------
# config : string
#     Full path of the config.yaml file.
#
# Shuffles: list, optional, default=[1]
#     List of integers specifying the shuffle indices of the training dataset.
#
# trainingsetindex: int or str, optional, default=0
#     Integer specifying which "TrainingsetFraction" to use.
# ...
